# %%
#write a program to printout all colors from colorset 1 not contained in color set2
input1=input("Enter colors for set 1(seperated by commas):")
input2=input("Enter colors for set 2(seperated by commas):")
color_set1={color.strip()for color in input1.split(",")}
color_set2={color.strip()for color in input2.split(",")}
print("orginal Set 1:",color_set1)
print("orginal Set 2:",color_set2)
result=color_set1-color_set2
print("Colors in set 1 not in set 2:",result)
# Out:
# Enter colors for set 1(seperated by commas):green,blue,yelloe,red
# Enter colors for set 2(seperated by commas):black,green,blue
# orginal Set 1: {'yelloe', 'red', 'blue', 'green'}
# orginal Set 2: {'blue', 'green', 'black'}
# Colors in set 1 not in set 2: {'red', 'yelloe'}

# %%
#combine all colors from setland set2
input1=input("Enter colors for set 1(seperated by commas):")
input2=input("Enter colors for set 2(seperated by commas):")
color_set1={color.strip()for color in input1.split(",")}
color_set2={color.strip()for color in input2.split(",")}
print("orginal Set 1:",color_set1)
print("orginal Set 2:",color_set2)
result=color_set1 | color_set2
print("All unique colors from both sets:",result)
# Out:
# Enter colors for set 1(seperated by commas):red,green,blue
# Enter colors for set 2(seperated by commas):blue,yellow,black
# orginal Set 1: {'green', 'blue', 'red'}
# orginal Set 2: {'yellow', 'blue', 'black'}
# All unique colors from both sets: {'yellow', 'green', 'red', 'black', 'blue'}
