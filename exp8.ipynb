# %%
#sort by roll number
students = {}

roll_no = int(input("Enter roll number for student 1: "))
name = input("Enter name for student 1: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 2: "))
name = input("Enter name for student 2: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 3: "))
name = input("Enter name for student 3: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 4: "))
name = input("Enter name for student 4: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 5: "))
name = input("Enter name for student 5: ")
students[roll_no] = name

asc_sorted = dict(sorted(students.items()))
desc_sorted = dict(sorted(students.items(), reverse=True))

print("\nOriginal Dictionary:", students)
print("Ascending order by roll no:", asc_sorted)
print("Descending order by roll no:", desc_sorted)
# Out:
# Enter roll number for student 1: 1
# Enter name for student 1: hisam
# Enter roll number for student 2: 2
# Enter name for student 2: safeer
# Enter roll number for student 3: 3
# Enter name for student 3: miya
# Enter roll number for student 4: 4
# Enter name for student 4: sana
# Enter roll number for student 5: 5
# Enter name for student 5: niranjana
#
# Original Dictionary: {1: 'hisam', 2: 'safeer', 3: 'miya', 4: 'sana', 5: 'niranjana'}
# Ascending order by roll no: {1: 'hisam', 2: 'safeer', 3: 'miya', 4: 'sana', 5: 'niranjana'}
# Descending order by roll no: {5: 'niranjana', 4: 'sana', 3: 'miya', 2: 'safeer', 1: 'hisam'}

# %%
# merging two dictionaries
dic1 = {}

roll_no = int(input("Enter roll number for student 1: "))
name = input("Enter name for student 1: ")
dic1[roll_no] = name

roll_no = int(input("Enter roll number for student 2: "))
name = input("Enter name for student 2: ")
dic1[roll_no] = name

roll_no = int(input("Enter roll number for student 3: "))
name = input("Enter name for student 3: ")
dic1[roll_no] = name


dic2 = {}

roll_no = int(input("Enter roll number for student 1: "))
name = input("Enter name for student 1: ")
dic2[roll_no] = name

roll_no = int(input("Enter roll number for student 2: "))
name = input("Enter name for student 2: ")
dic2[roll_no] = name


print("Dictionary 1:", dic1)
print("Dictionary 2:", dic2)

dic1.update(dic2)

print("\nMerged Dictionary:", dic1)
# Out:
# Enter roll number for student 1: 1
# Enter name for student 1: hisam
# Enter roll number for student 2: 2
# Enter name for student 2: safeer
# Enter roll number for student 3: 3
# Enter name for student 3: miya
# Enter roll number for student 1: 1
# Enter name for student 1: hisam
# Enter roll number for student 2: 3
# Enter name for student 2: sana
# Dictionary 1: {1: 'hisam', 2: 'safeer', 3: 'miya'}
# Dictionary 2: {1: 'hisam', 3: 'sana'}
#
# Merged Dictionary: {1: 'hisam', 2: 'safeer', 3: 'sana'}
