# %%
print("welcome")
# Out:
# welcome

# %%
print("hisam mohammed")
print("othukungal.malappuram")
# Out:
# hisam mohammed
# othukungal.malappuram

# %%
print3hjk3hj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print3hjk3hj
#
# NameError: name 'print3hjk3hj' is not defined

# %%
PRINT("HISAM")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 PRINT("HISAM")
#
# NameError: name 'PRINT' is not defined

# %%
print("5/2")
# Out:
# 5/2

# %%
print("5%2")
# Out:
# 5%2

# %%
print(5//2)
# Out:
# 2

# %%
int(5/2)
# Out:
# 2

# %%
print(2**2)
# Out:
# 4

# %%
print("KSB'S STUDENTS")
# Out:
# KSB'S STUDENTS

# %%
print("KSB'S// STUDENTS")
# Out:
# KSB'S// STUDENTS

# %%
print('"ksb"students')
# Out:
# "ksb"students

# %%
print("ksb's"students)
# Out:
#   Cell In[13], line 1
#     print("ksb's"students)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
