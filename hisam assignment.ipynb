# %%
# Out:
# enter an integer:5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 n=int(input("enter an integer:"))
# ----> 2 result=n+nn+nnn
#       3 print(result)
#
# NameError: name 'nn' is not defined

# %%
#COMPUTE THE VALUE OF N+NN+NN
n=input("enter an integer:")
nn=n+n
nnn=n+n+n
sum=int(n)+int(nn)+int(nnn)

print("result:",n,"+",nn,"+",nnn,"=",sum)
# Out:
# enter an integer:8
# result: 8 + 88 + 888 = 984

# %%
#input radius of a circlr and compute the area
import math
r=int(input("enter a number:"))
area=math.pi *r*r
print("area of circle",round(area,2))
# Out:
# enter a number:5
# area of circle 78.54

# %%
#FIND THE BIGGEST THREE NUMBERS
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
biggest=max(a,b,c)
print("the biggest number is:",biggest)
# Out:
# enter the first number:5
# enter the second number:3
# enter the third number:2
# the biggest number is: 5
